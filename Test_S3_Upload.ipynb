# %% [markdown]
# # Jupyter Notebook File to Upload All Data into S3 Bucket

# %%
# Install packages using sc.__install_pypi()

sc.install_pypi_package("boto3")
sc.install_pypi_package("requests")
sc.install_pypi_package("bs4")
# sc.install_pypi_package("DBUtils==2.0.2")
# Out:
# VBox()
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>0</td><td>application_1627073612398_0001</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-3-254.ec2.internal:20888/proxy/application_1627073612398_0001/" class="emr-proxy-link" emr-resource="j-1QXJEZTDE35AS
# " application-id="application_1627073612398_0001">Link</a></td><td><a target="_blank" href="http://ip-172-31-7-1.ec2.internal:8042/node/containerlogs/container_1627073612398_0001_01_000001/livy" >Link</a></td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Collecting boto3
#   Downloading https://files.pythonhosted.org/packages/54/5e/a790a07b2e4c6de53c58e339c01207d1cceb45e0326b80fecc071aa9f884/boto3-1.18.6-py3-none-any.whl (131kB)
# Collecting botocore<1.22.0,>=1.21.6 (from boto3)
#   Downloading https://files.pythonhosted.org/packages/11/bc/0acb2112d92df3815276b6aed58a0e324d891e510b7c46c987fac950c0a7/botocore-1.21.6-py3-none-any.whl (7.7MB)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/site-packages (from boto3)
# Collecting s3transfer<0.6.0,>=0.5.0 (from boto3)
#   Downloading https://files.pythonhosted.org/packages/ab/84/fc3717a7b7f0f6bb08af593127171f08e3e0087c197922da09c01bfe7c3a/s3transfer-0.5.0-py3-none-any.whl (79kB)
# Collecting urllib3<1.27,>=1.25.4 (from botocore<1.22.0,>=1.21.6->boto3)
#   Downloading https://files.pythonhosted.org/packages/5f/64/43575537846896abac0b15c3e5ac678d787a4021e906703f1766bfb8ea11/urllib3-1.26.6-py2.py3-none-any.whl (138kB)
# Collecting python-dateutil<3.0.0,>=2.1 (from botocore<1.22.0,>=1.21.6->boto3)
#   Downloading https://files.pythonhosted.org/packages/36/7a/87837f39d0296e723bb9b62bbb257d0355c7f6128853c78955f57342a56d/python_dateutil-2.8.2-py2.py3-none-any.whl (247kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.22.0,>=1.21.6->boto3)
# Installing collected packages: urllib3, python-dateutil, botocore, s3transfer, boto3
# Successfully installed boto3-1.18.6 botocore-1.21.6 python-dateutil-2.8.2 s3transfer-0.5.0 urllib3-1.26.6
#
# Collecting requests
#   Downloading https://files.pythonhosted.org/packages/92/96/144f70b972a9c0eabbd4391ef93ccd49d0f2747f4f6a2a2738e99e5adc65/requests-2.26.0-py2.py3-none-any.whl (62kB)
# Collecting idna<4,>=2.5; python_version >= "3" (from requests)
#   Downloading https://files.pythonhosted.org/packages/d7/77/ff688d1504cdc4db2a938e2b7b9adee5dd52e34efbd2431051efc9984de9/idna-3.2-py3-none-any.whl (59kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /mnt/tmp/1627073963340-0/lib/python3.7/site-packages (from requests)
# Collecting charset-normalizer~=2.0.0; python_version >= "3" (from requests)
#   Downloading https://files.pythonhosted.org/packages/c4/1d/e6ce112f7237fc746e632e1cbdc24890cad95505c6cd4b711f4fd17f4735/charset_normalizer-2.0.3-py3-none-any.whl
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading https://files.pythonhosted.org/packages/05/1b/0a0dece0e8aa492a6ec9e4ad2fe366b511558cdc73fd3abc82ba7348e875/certifi-2021.5.30-py2.py3-none-any.whl (145kB)
# Installing collected packages: idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2021.5.30 charset-normalizer-2.0.3 idna-3.2 requests-2.26.0
#
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/site-packages (from bs4)
# Collecting soupsieve>1.2 (from beautifulsoup4->bs4)
#   Downloading https://files.pythonhosted.org/packages/36/69/d82d04022f02733bf9a72bc3b96332d360c0c5307096d76f6bb7489f7e57/soupsieve-2.2.1-py3-none-any.whl
# Building wheels for collected packages: bs4
#   Running setup.py bdist_wheel for bs4: started
#   Running setup.py bdist_wheel for bs4: finished with status 'done'
#   Stored in directory: /var/lib/livy/.cache/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: bs4, soupsieve
# Successfully installed bs4-0.0.1 soupsieve-2.2.1

# %%
# sc.install_pypi_package("numpy==1.17.3")
# sc.install_pypi_package("pandas==0.25.1")
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# sc.install_pypi_package("s3fs")
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# dbutils.fs.help()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Import packages
import logging
import os
import zipfile
import io

import boto3
from boto3 import client
import requests
from bs4 import BeautifulSoup
from pyspark.sql import SparkSession
from pyspark.sql.functions import isnan, when, count, col
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Start Spark context manager
spark = SparkSession.builder \
    .master("local") \
    .appName("OE Capstone App") \
    .getOrCreate()
sc = spark.sparkContext
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Data Pipeline Class
class DataPipeline:
    """
    This DataPipeline class will simply be used to take an website url as a data source and
    an S3 object as a possible data storage destination. An EL method is also created with
    description as follows, in addition to a single method to read and transform.
    """

    def __init__(self, s3_cli_object, s3_resource, s3_bucket, bucket_path, url):
        """
        For this method, we can either have some s3_obj or a cloud path variable.
        We can set these values to None first, then change it later.
        """
        self.s3_cli_object = s3_cli_object
        self.s3_resource = s3_resource
        self.s3_bucket_name = s3_bucket
        self.bucket_path = bucket_path
        self.url = url

    def extract_load(self):
        """
        Function has three main steps to perform ELT based on "use_cloud" boolean parameter:
        1) Extract (scrape) data from GDELT website HTML document.
        2. Load data into S3 Bucket
        """
        # Log to file
        logging.basicConfig(filename='elt.log', level=logging.INFO)
        # Extract data from HTML webpage
        url = self.url
        page = requests.get(url)
        # Create BeautifulSoup object to parse through HTML document
        soup = BeautifulSoup(page.content, "html.parser")
        # Base url for file downloading
        base_url = url[:-10]
        # Current Directory -> we do not need for Step 6.
        current_directory = os.getcwd()
        # Cloud Path -> Will use this variable to store data and refer to when applying Spark transformations -> spark.read.csv(cloud_path + f"{file}")
        cloud_path = self.bucket_path
        # Create S3 client instance
        s3_client = self.s3_cli_object
        # Bucket name
        destination_bucket = self.s3_bucket_name

        # Iterate to obtain all we want to download ALL DATA FROM HTML Document
        # based on "a" and "href" tags in order to extract data, use PySpark to efficiently process data
        # and save the data to new CSV file inside AWS S3 bucket.
        
        # UNCOMMENT FOR TO SCRAPE ALL
        # for link in soup.find_all("a")[2:]:
        for link in soup.find_all("a")[2:1000]:  # TODO: Test only 3 files to see if I am successfully able to upload these files to S3.
            try:
                if link.has_attr("href"):
                    # Obtain file name as string object
                    file = link.attrs["href"]
                    download_url = f"{base_url}{file}"
                    csv_file_str = file[:-4]
                    print(csv_file_str)
                    # Request data from URL and extract data as CSV to current (S3) directory using EMR Notebook
                    response = requests.get(download_url)
                    zip_file = zipfile.ZipFile(io.BytesIO(response.content))
                    # zip_file.extractall()

                    # Similar to MSharp's approach --> Play w/ response.content/parsed HTML document instead.
                    data = zip_file.read(csv_file_str)
                    local_path = "/tmp/" + csv_file_str
                    s3_key = csv_file_str
                    # Write to local path --> Think how to do this inside EMR Cluster. I will create tmp directory.
                    with open(local_path, "wb") as f:
                        f.write(data)
                        del data
                        print("Created csv file and removed original zip file object.")
                    # S3 Bucket
                    s3_client.upload_file(local_path, destination_bucket, s3_key)
                    print("File uploaded to S3 bucket.")
            except Exception as e:
                logging.error(f"Error was {e}")
                
    def spark_read_transform(self):
        """
        1. Search for proper S3 bucket.
        2. Read both files using Spark.
        3. Apply data transformations.
        4. Save to CSV file.
        """        
        # Create s3 resource object
        s3 = self.s3_resource

        # Iterate through each file in desired S3 bucket
        for bucket in s3.buckets.all():
            # print(bucket)
            if bucket == s3.Bucket(name='openendedcapstone'):
                print("OEC.")
                # Try to do more stuff.
                for key in bucket.objects.all():
                    # print(key.key)
                    if ".gkgcounts.csv" in key.key:
                        # print(key.key)
                        # Test to see if I can at least read a file called key.key:
                        file_path = self.bucket_path + key.key
                        spark_df2 = spark.read.csv(file_path, header=True, sep="\t")
                        print("Showing results of Spark DataFrame 2: \n")
                        spark_df2.limit(3).show()

                        
                        # Transformations
                        spark_df2 = spark_df2.withColumn("NUMARTS", spark_df2["NUMARTS"].cast("int"))\
                                .withColumn("NUMBER", spark_df2["NUMBER"].cast("int"))\
                                .withColumn("GEO_TYPE", spark_df2["GEO_TYPE"].cast("int"))\
                                .withColumn("GEO_LAT", spark_df2["GEO_LAT"].cast("float"))\
                                .withColumn("GEO_LONG", spark_df2["GEO_LONG"].cast("float"))\
                                .drop("DATE")
#                         spark_df2.limit(3).show()
                        save_location = "s3://openendedcapstone/Data_Stream_2/"
                        file_location = save_location + key.key
                        spark_df2.repartition(1).write.csv(path=file_location, header=True, sep="\t")
                        print("Wrote to CSV file.")
                    elif ".gkg.csv" in key.key:
                        # Apply data transformations:
                        # 1) Drop "COUNTS" column.
                        # 2) Change NUMARTS to integer.
                        file_path = self.bucket_path + key.key
                        spark_df1 = spark.read.csv(file_path, header=True, sep="\t")
                        print("Showing results of Spark DataFrame 1: \n")
                        # spark_df1.limit(3).show()
 
                        # Apply Transformations
                        spark_df1 = spark_df1.withColumn("NUMARTS", spark_df1["NUMARTS"].cast("int"))\
                        .drop("DATE", "COUNTS")
                        print("Spark DF 1 Transformed.")
#                         spark_df1.limit(3).show()
                        # Write Back to CSV file
                        save_location = "s3://openendedcapstone/Data_Stream_1/"
                        file_location = save_location + key.key
                        spark_df1.repartition(1).write.csv(path=file_location, header=True, sep="\t")
                        print("Wrote to CSV File.")    
        
    def s3_copy_delete(self):
        """
        This method will copy and delete files from S3 bucket to ensure I have
        desired files inside Data_Stream_1 Folder and Data_Stream_2 Folder.
        """
        # Alternative approach
        s3 = self.s3_resource
        # s3 = self.s3_cli_object
        s3_bucket_name = self.s3_bucket_name

        for bucket in s3.buckets.all():
            # print(bucket)
            if bucket == s3.Bucket(name='openendedcapstone'):
                print("OEC.")
                # Try to do more stuff.
                for key in bucket.objects.all():
                    # print(key.key)
                    if "Data_Stream_2/" and "part" in key.key:
                        print(key.key)
                        # Split string on "/" and take first two                         
                        file_to_move = key.key
                        file_char = file_to_move.split("/")
                        # print(file_char[0:2])
                        sep_list = file_char[:]
                        insert_at = 1
                        sep_list[insert_at:insert_at] = ["/"]
                        print(sep_list)
                        file_char = sep_list[0:3]
                        file_str = "".join(file_char)
                        print(file_str)
                        s3.Object("openendedcapstone", file_str)\
                         .copy_from(CopySource="openendedcapstone/" + key.key)
                        s3.Object("openendedcapstone", key.key).delete()
                    elif "Data_Stream_1/" and "part" in key.key:
                        print(key.key)
                        # Split string on "/" and take first two                         
                        file_to_move = key.key
                        file_char = file_to_move.split("/")
                        # print(file_char[0:2])
                        sep_list = file_char[:]
                        insert_at = 1
                        sep_list[insert_at:insert_at] = ["/"]
                        print(sep_list)
                        file_char = sep_list[0:3]
                        file_str = "".join(file_char)
                        print(file_str)
                        s3.Object("openendedcapstone", file_str)\
                         .copy_from(CopySource="openendedcapstone/" + key.key)
                        s3.Object("openendedcapstone", key.key).delete()
    
    
    def remove_zip_files(self):
        """
        Sample of what to do if I have zip files.
        This needs to be updated, but it is good to think about what I can do.
        """
        # Cloud path to unzip
        cloud_path = self.s3_bucket_path
        # Get a list of all the file paths that ends with .txt from in specified directory
        file_list = glob.glob(cloud_path + '*.zip')
        # Iterate over the list of file paths & remove each file.
        for file_path in file_list:
            try:
                os.remove(file_path)
            except Exception as e:
                logging.error(f"Error removing file: {e}")
                
    def remove_file_folders(self):
        """
        This method will be used to remove all file folders.
        """
        s3 = self.s3_resource
        s3_bucket_name = self.s3_bucket_name

        for bucket in s3.buckets.all():
            # print(bucket)
            if bucket == s3.Bucket(name='openendedcapstone'):
                print("OEC.")
                for key in bucket.objects.all():
#                     print(key.key)
                    if "Data_Stream_1" and ".csv/" in key.key:
                        print(key.key[:-8])
                        bucket.objects.filter(Prefix=key.key[:-8]).delete()
                        print("Data_Stream_1 Subfolders deleted.")
                    elif "Data_Stream_2" and ".csv/" in key.key:
                        print(key.key[:-8])
                        bucket.objects.filter(Prefix=key.key[:-8]).delete()
                        print("Data_Stream_2 Subfolders deleted.")
                        
    def remove_other_files(self):
        s3 = self.s3_resource
        s3_bucket_name = self.s3_bucket_name

        for bucket in s3.buckets.all():
            # print(bucket)
            if bucket == s3.Bucket(name='openendedcapstone'):
                print("OEC.")
                for key in bucket.objects.all():
                    if ("Data_Stream_1" not in key.key) and (".csv" in key.key):
                        print(key.key[:-8])
                        bucket.objects.filter(Prefix=key.key[:-8]).delete()
                        print("Other Files deleted.")
                    elif ("Data_Stream_2" not in key.key) and (".csv" in key.key):
                        print(key.key[:-8])
                        bucket.objects.filter(Prefix=key.key[:-8]).delete()
                        print("Other files deleted.")
                        
    def remove_all_files(self):
        s3 = self.s3_resource
        s3_bucket_name = self.s3_bucket_name

        for bucket in s3.buckets.all():
            # print(bucket)
            if bucket == s3.Bucket(name='openendedcapstone'):
                print("OEC.")
                for key in bucket.objects.all():
                    if ".csv" in key.key:
                        print(key.key[:-8])
                        bucket.objects.filter(Prefix=key.key[:-8]).delete()
                        print("All Files deleted.")
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Instead, create S3 client object
s3_client_obj = boto3.client("s3")
s3_resource = boto3.resource("s3")


# S3 Bucket name
s3_bucket_name = "openendedcapstone"

# Instead, use AWS Educate's S3 Bucket path
# s3_bucket_path = "s3a://openendedcapstone/"
s3_bucket_path = "s3://openendedcapstone/"

# Obtain url
website_url = "http://data.gdeltproject.org/gkg/index.html"

# Create data pipeline (use s3 object as input) - this will ask if you want to using s3 boto3 object and s3_uri_path object.
dp = DataPipeline(s3_cli_object=s3_client_obj, s3_resource=s3_resource, s3_bucket=s3_bucket_name, bucket_path=s3_bucket_path, url=website_url)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# OLD: Test extract_load_transform()
# dp.extract_load_transform()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
dp.extract_load()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# --- Logging error ---
# Traceback (most recent call last):
#   File "/mnt/notebook-env/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/mnt/notebook-env/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/mnt/notebook-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/mnt/notebook-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/pysparkkernel/pysparkkernel.py", line 28, in <module>
#     IPKernelApp.launch_instance(kernel_class=PySparkKernel)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/base_events.py", line 534, in run_forever
#     self._run_once()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/base_events.py", line 1771, in _run_once
#     handle._run()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 58, in do_execute
#     return wrap_unexpected_exceptions(f, self._complete_cell)(self)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 107, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 57, in f
#     return self._do_execute(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 69, in _do_execute
#     res = self._execute_cell(code_to_run, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 105, in _execute_cell
#     reply_content = self._execute_cell_for_user(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 116, in _execute_cell_for_user
#     result = super(SparkKernelBase, self).do_execute(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-849ad79f1672>", line 1, in <module>
#     get_ipython().run_cell_magic('spark', '', 'dp.extract_load()\n')
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2399, in run_cell_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-116>", line 2, in spark
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 107, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 74, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/kernelmagics.py", line 278, in spark
#     self.execute_spark(cell, args.output, args.samplemethod, args.maxrows, args.samplefraction, None, coerce)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/magics/sparkmagicsbase.py", line 82, in execute_spark
#     (success, out, mimetype) = self.spark_controller.run_command(Command(cell), session_name)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/sparkcontroller.py", line 42, in run_command
#     return command.execute(session_to_use)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/command.py", line 44, in execute
#     output = self._get_statement_output(session, statement_id)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/command.py", line 72, in _get_statement_output
#     self.logger.debug(u"Status of statement {} is {}.".format(statement_id, status))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/hdijupyterutils/log.py", line 21, in debug
#     self.logger.debug(self._transform_log_message(message))
# Message: 'Command\tStatus of statement 8 is running.'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/mnt/notebook-env/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/mnt/notebook-env/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/mnt/notebook-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/mnt/notebook-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/pysparkkernel/pysparkkernel.py", line 28, in <module>
#     IPKernelApp.launch_instance(kernel_class=PySparkKernel)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/base_events.py", line 534, in run_forever
#     self._run_once()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/base_events.py", line 1771, in _run_once
#     handle._run()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 58, in do_execute
#     return wrap_unexpected_exceptions(f, self._complete_cell)(self)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 107, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 57, in f
#     return self._do_execute(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 69, in _do_execute
#     res = self._execute_cell(code_to_run, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 105, in _execute_cell
#     reply_content = self._execute_cell_for_user(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 116, in _execute_cell_for_user
#     result = super(SparkKernelBase, self).do_execute(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-849ad79f1672>", line 1, in <module>
#     get_ipython().run_cell_magic('spark', '', 'dp.extract_load()\n')
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2399, in run_cell_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-116>", line 2, in spark
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 107, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 74, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/kernelmagics.py", line 278, in spark
#     self.execute_spark(cell, args.output, args.samplemethod, args.maxrows, args.samplefraction, None, coerce)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/magics/sparkmagicsbase.py", line 82, in execute_spark
#     (success, out, mimetype) = self.spark_controller.run_command(Command(cell), session_name)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/sparkcontroller.py", line 42, in run_command
#     return command.execute(session_to_use)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/command.py", line 44, in execute
#     output = self._get_statement_output(session, statement_id)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/command.py", line 72, in _get_statement_output
#     self.logger.debug(u"Status of statement {} is {}.".format(statement_id, status))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/hdijupyterutils/log.py", line 21, in debug
#     self.logger.debug(self._transform_log_message(message))
# Message: 'Command\tStatus of statement 8 is running.'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/mnt/notebook-env/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/mnt/notebook-env/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/mnt/notebook-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/mnt/notebook-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/pysparkkernel/pysparkkernel.py", line 28, in <module>
#     IPKernelApp.launch_instance(kernel_class=PySparkKernel)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/base_events.py", line 534, in run_forever
#     self._run_once()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/base_events.py", line 1771, in _run_once
#     handle._run()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 58, in do_execute
#     return wrap_unexpected_exceptions(f, self._complete_cell)(self)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 107, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 57, in f
#     return self._do_execute(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 69, in _do_execute
#     res = self._execute_cell(code_to_run, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 105, in _execute_cell
#     reply_content = self._execute_cell_for_user(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 116, in _execute_cell_for_user
#     result = super(SparkKernelBase, self).do_execute(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-849ad79f1672>", line 1, in <module>
#     get_ipython().run_cell_magic('spark', '', 'dp.extract_load()\n')
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2399, in run_cell_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-116>", line 2, in spark
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 107, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 74, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/kernelmagics.py", line 278, in spark
#     self.execute_spark(cell, args.output, args.samplemethod, args.maxrows, args.samplefraction, None, coerce)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/magics/sparkmagicsbase.py", line 82, in execute_spark
#     (success, out, mimetype) = self.spark_controller.run_command(Command(cell), session_name)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/sparkcontroller.py", line 42, in run_command
#     return command.execute(session_to_use)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/command.py", line 44, in execute
#     output = self._get_statement_output(session, statement_id)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/command.py", line 72, in _get_statement_output
#     self.logger.debug(u"Status of statement {} is {}.".format(statement_id, status))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/hdijupyterutils/log.py", line 21, in debug
#     self.logger.debug(self._transform_log_message(message))
# Message: 'Command\tStatus of statement 8 is running.'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/mnt/notebook-env/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/mnt/notebook-env/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/mnt/notebook-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/mnt/notebook-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/pysparkkernel/pysparkkernel.py", line 28, in <module>
#     IPKernelApp.launch_instance(kernel_class=PySparkKernel)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/base_events.py", line 534, in run_forever
#     self._run_once()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/base_events.py", line 1771, in _run_once
#     handle._run()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 58, in do_execute
#     return wrap_unexpected_exceptions(f, self._complete_cell)(self)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 107, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 57, in f
#     return self._do_execute(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 69, in _do_execute
#     res = self._execute_cell(code_to_run, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 105, in _execute_cell
#     reply_content = self._execute_cell_for_user(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 116, in _execute_cell_for_user
#     result = super(SparkKernelBase, self).do_execute(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-849ad79f1672>", line 1, in <module>
#     get_ipython().run_cell_magic('spark', '', 'dp.extract_load()\n')
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2399, in run_cell_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-116>", line 2, in spark
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 107, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 74, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/kernelmagics.py", line 278, in spark
#     self.execute_spark(cell, args.output, args.samplemethod, args.maxrows, args.samplefraction, None, coerce)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/magics/sparkmagicsbase.py", line 82, in execute_spark
#     (success, out, mimetype) = self.spark_controller.run_command(Command(cell), session_name)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/sparkcontroller.py", line 42, in run_command
#     return command.execute(session_to_use)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/command.py", line 44, in execute
#     output = self._get_statement_output(session, statement_id)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/command.py", line 72, in _get_statement_output
#     self.logger.debug(u"Status of statement {} is {}.".format(statement_id, status))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/hdijupyterutils/log.py", line 21, in debug
#     self.logger.debug(self._transform_log_message(message))
# Message: 'Command\tStatus of statement 8 is running.'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/mnt/notebook-env/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/mnt/notebook-env/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/mnt/notebook-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/mnt/notebook-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/pysparkkernel/pysparkkernel.py", line 28, in <module>
#     IPKernelApp.launch_instance(kernel_class=PySparkKernel)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/base_events.py", line 534, in run_forever
#     self._run_once()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/base_events.py", line 1771, in _run_once
#     handle._run()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 58, in do_execute
#     return wrap_unexpected_exceptions(f, self._complete_cell)(self)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 107, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 57, in f
#     return self._do_execute(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 69, in _do_execute
#     res = self._execute_cell(code_to_run, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 105, in _execute_cell
#     reply_content = self._execute_cell_for_user(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 116, in _execute_cell_for_user
#     result = super(SparkKernelBase, self).do_execute(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-849ad79f1672>", line 1, in <module>
#     get_ipython().run_cell_magic('spark', '', 'dp.extract_load()\n')
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2399, in run_cell_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-116>", line 2, in spark
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 107, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 74, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/kernelmagics.py", line 278, in spark
#     self.execute_spark(cell, args.output, args.samplemethod, args.maxrows, args.samplefraction, None, coerce)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/magics/sparkmagicsbase.py", line 82, in execute_spark
#     (success, out, mimetype) = self.spark_controller.run_command(Command(cell), session_name)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/sparkcontroller.py", line 42, in run_command
#     return command.execute(session_to_use)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/command.py", line 44, in execute
#     output = self._get_statement_output(session, statement_id)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/command.py", line 72, in _get_statement_output
#     self.logger.debug(u"Status of statement {} is {}.".format(statement_id, status))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/hdijupyterutils/log.py", line 21, in debug
#     self.logger.debug(self._transform_log_message(message))
# Message: 'Command\tStatus of statement 8 is running.'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/mnt/notebook-env/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/mnt/notebook-env/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/mnt/notebook-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/mnt/notebook-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/pysparkkernel/pysparkkernel.py", line 28, in <module>
#     IPKernelApp.launch_instance(kernel_class=PySparkKernel)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/base_events.py", line 534, in run_forever
#     self._run_once()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/base_events.py", line 1771, in _run_once
#     handle._run()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 58, in do_execute
#     return wrap_unexpected_exceptions(f, self._complete_cell)(self)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 107, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 57, in f
#     return self._do_execute(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 69, in _do_execute
#     res = self._execute_cell(code_to_run, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 105, in _execute_cell
#     reply_content = self._execute_cell_for_user(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 116, in _execute_cell_for_user
#     result = super(SparkKernelBase, self).do_execute(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-849ad79f1672>", line 1, in <module>
#     get_ipython().run_cell_magic('spark', '', 'dp.extract_load()\n')
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2399, in run_cell_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-116>", line 2, in spark
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 107, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 74, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/kernelmagics.py", line 278, in spark
#     self.execute_spark(cell, args.output, args.samplemethod, args.maxrows, args.samplefraction, None, coerce)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/magics/sparkmagicsbase.py", line 82, in execute_spark
#     (success, out, mimetype) = self.spark_controller.run_command(Command(cell), session_name)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/sparkcontroller.py", line 42, in run_command
#     return command.execute(session_to_use)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/command.py", line 44, in execute
#     output = self._get_statement_output(session, statement_id)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/command.py", line 72, in _get_statement_output
#     self.logger.debug(u"Status of statement {} is {}.".format(statement_id, status))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/hdijupyterutils/log.py", line 21, in debug
#     self.logger.debug(self._transform_log_message(message))
# Message: 'Command\tStatus of statement 8 is running.'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/mnt/notebook-env/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/mnt/notebook-env/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/mnt/notebook-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/mnt/notebook-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/pysparkkernel/pysparkkernel.py", line 28, in <module>
#     IPKernelApp.launch_instance(kernel_class=PySparkKernel)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/base_events.py", line 534, in run_forever
#     self._run_once()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/base_events.py", line 1771, in _run_once
#     handle._run()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 58, in do_execute
#     return wrap_unexpected_exceptions(f, self._complete_cell)(self)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 107, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 57, in f
#     return self._do_execute(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 69, in _do_execute
# ...
# 20200326.gkg.csv
# 20200326.gkgcounts.csv
# 20200325.gkg.csv
# 20200325.gkgcounts.csv
# 20200324.gkg.csv
# 20200324.gkgcounts.csv
# 20200323.gkg.csv
# 20200323.gkgcounts.csv
# 20200322.gkg.csv
# 20200322.gkgcounts.csv
# 20200321.gkg.csv
# 20200321.gkgcounts.csv
# 20200320.gkg.csv
# 20200320.gkgcounts.csv
# 20200319.gkg.csv
# 20200319.gkgcounts.csv
# 20200318.gkg.csv
# 20200318.gkgcounts.csv
# 20200317.gkg.csv
# 20200317.gkgcounts.csv
# 20200316.gkg.csv
# 20200316.gkgcounts.csv
# 20200315.gkg.csv
# 20200315.gkgcounts.csv
# 20200314.gkg.csv
# 20200314.gkgcounts.csv
# 20200313.gkg.csv
# 20200313.gkgcounts.csv
# 20200312.gkg.csv
# 20200312.gkgcounts.csv
# 20200311.gkg.csv
# 20200311.gkgcounts.csv
# --- Logging error ---
# Traceback (most recent call last):
#   File "/mnt/notebook-env/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/mnt/notebook-env/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/mnt/notebook-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/mnt/notebook-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/pysparkkernel/pysparkkernel.py", line 28, in <module>
#     IPKernelApp.launch_instance(kernel_class=PySparkKernel)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/base_events.py", line 534, in run_forever
#     self._run_once()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/base_events.py", line 1771, in _run_once
#     handle._run()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 58, in do_execute
#     return wrap_unexpected_exceptions(f, self._complete_cell)(self)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 107, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 57, in f
#     return self._do_execute(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 69, in _do_execute
#     res = self._execute_cell(code_to_run, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 105, in _execute_cell
#     reply_content = self._execute_cell_for_user(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 116, in _execute_cell_for_user
#     result = super(SparkKernelBase, self).do_execute(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-849ad79f1672>", line 1, in <module>
#     get_ipython().run_cell_magic('spark', '', 'dp.extract_load()\n')
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2399, in run_cell_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-116>", line 2, in spark
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 107, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 74, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/kernelmagics.py", line 278, in spark
#     self.execute_spark(cell, args.output, args.samplemethod, args.maxrows, args.samplefraction, None, coerce)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/magics/sparkmagicsbase.py", line 82, in execute_spark
#     (success, out, mimetype) = self.spark_controller.run_command(Command(cell), session_name)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/sparkcontroller.py", line 42, in run_command
#     return command.execute(session_to_use)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/command.py", line 44, in execute
#     output = self._get_statement_output(session, statement_id)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/command.py", line 72, in _get_statement_output
#     self.logger.debug(u"Status of statement {} is {}.".format(statement_id, status))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/hdijupyterutils/log.py", line 21, in debug
#     self.logger.debug(self._transform_log_message(message))
# Message: 'Command\tStatus of statement 8 is available.'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/mnt/notebook-env/lib/python3.7/logging/__init__.py", line 1029, in emit
#     self.flush()
#   File "/mnt/notebook-env/lib/python3.7/logging/__init__.py", line 1009, in flush
#     self.stream.flush()
# OSError: [Errno 28] No space left on device
# Call stack:
#   File "/mnt/notebook-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/mnt/notebook-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/pysparkkernel/pysparkkernel.py", line 28, in <module>
#     IPKernelApp.launch_instance(kernel_class=PySparkKernel)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/base_events.py", line 534, in run_forever
#     self._run_once()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/base_events.py", line 1771, in _run_once
#     handle._run()
#   File "/mnt/notebook-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 58, in do_execute
#     return wrap_unexpected_exceptions(f, self._complete_cell)(self)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 107, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 57, in f
#     return self._do_execute(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 69, in _do_execute
#     res = self._execute_cell(code_to_run, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 105, in _execute_cell
#     reply_content = self._execute_cell_for_user(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/wrapperkernel/sparkkernelbase.py", line 116, in _execute_cell_for_user
#     result = super(SparkKernelBase, self).do_execute(code, silent, store_history, user_expressions, allow_stdin)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-849ad79f1672>", line 1, in <module>
#     get_ipython().run_cell_magic('spark', '', 'dp.extract_load()\n')
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2399, in run_cell_magic
#     result = fn(*args, **kwargs)
#   File "<decorator-gen-116>", line 2, in spark
#   File "/mnt/notebook-env/lib/python3.7/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 107, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/exceptions.py", line 74, in wrapped
#     out = f(self, *args, **kwargs)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/kernels/kernelmagics.py", line 278, in spark
#     self.execute_spark(cell, args.output, args.samplemethod, args.maxrows, args.samplefraction, None, coerce)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/magics/sparkmagicsbase.py", line 82, in execute_spark
#     (success, out, mimetype) = self.spark_controller.run_command(Command(cell), session_name)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/sparkcontroller.py", line 42, in run_command
#     return command.execute(session_to_use)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/livyclientlib/command.py", line 52, in execute
#     self.guid, statement_id, True, "", "")
#   File "/mnt/notebook-env/lib/python3.7/site-packages/sparkmagic/utils/sparkevents.py", line 147, in emit_statement_execution_end_event
#     self.send_to_handler(kwargs_list)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/hdijupyterutils/events.py", line 21, in send_to_handler
#     self.handler.handle_event(kwargs_list)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/hdijupyterutils/eventshandler.py", line 13, in handle_event
#     self.logger.info(event_line)
#   File "/mnt/notebook-env/lib/python3.7/site-packages/hdijupyterutils/log.py", line 27, in info
#     self.logger.info(self._transform_log_message(message))
# Message: 'EventsHandler\tInstanceId: 0bb5d2db-3d79-46ab-abbf-87725b7c7cc6,EventName: notebookStatementExecutionEnd,Timestamp: 2021-07-23 21:23:51.839635,SessionGuid: 8f3ad9f1-1d68-40b2-b8b6-0fe872ad24ec,LivyKind: pyspark,SessionId: 0,StatementGuid: e260c08c-d588-4abd-bf8c-282e29ed13cf,StatementId: 8,Success: True,ExceptionType: ,ExceptionMessage: '
# Arguments: ()

# %%
dp.spark_read_transform()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# S3 Bucket Path to search: s3://openendedcapstone/
# Created Data Stream 2 File Path: s3://openendedcapstone/Data_Stream_2/
# OEC.
# Showing results of Spark DataFrame 2:
#
# +--------+-------+--------------------+------+----------+--------+--------------------+---------------+------------+-------+--------+-------------+--------------------+--------------------+--------------------+
# |    DATE|NUMARTS|           COUNTTYPE|NUMBER|OBJECTTYPE|GEO_TYPE|        GEO_FULLNAME|GEO_COUNTRYCODE|GEO_ADM1CODE|GEO_LAT|GEO_LONG|GEO_FEATUREID|       CAMEOEVENTIDS|             SOURCES|          SOURCEURLS|
# +--------+-------+--------------------+------+----------+--------+--------------------+---------------+------------+-------+--------+-------------+--------------------+--------------------+--------------------+
# |20210719|      2|               WOUND|     5|      null|       1|      United Kingdom|             UK|          UK|     54|      -4|           UK| 995664330,995664330|fermanaghherald.c...|https://fermanagh...|
# |20210719|      1|CRISISLEX_T09_DIS...|     3|      null|       2|Oregon, United St...|             US|        USOR|44.5672|-122.127|           OR|           995722144|  union-bulletin.com|https://www.union...|
# |20210719|      1|              AFFECT|     1|      null|       4|Kaseya, Kaduna, N...|             NI|        NI23|10.3463| 7.15295|     -2014903|995763692,9957297...|         guardian.ng|https://guardian....|
# +--------+-------+--------------------+------+----------+--------+--------------------+---------------+------------+-------+--------+-------------+--------------------+--------------------+--------------------+
#
# +-------+--------------------+------+----------+--------+--------------------+---------------+------------+-------+--------+-------------+--------------------+--------------------+--------------------+
# |NUMARTS|           COUNTTYPE|NUMBER|OBJECTTYPE|GEO_TYPE|        GEO_FULLNAME|GEO_COUNTRYCODE|GEO_ADM1CODE|GEO_LAT|GEO_LONG|GEO_FEATUREID|       CAMEOEVENTIDS|             SOURCES|          SOURCEURLS|
# +-------+--------------------+------+----------+--------+--------------------+---------------+------------+-------+--------+-------------+--------------------+--------------------+--------------------+
# |      2|               WOUND|     5|      null|       1|      United Kingdom|             UK|          UK|   54.0|    -4.0|           UK| 995664330,995664330|fermanaghherald.c...|https://fermanagh...|
# |      1|CRISISLEX_T09_DIS...|     3|      null|       2|Oregon, United St...|             US|        USOR|44.5672|-122.127|           OR|           995722144|  union-bulletin.com|https://www.union...|
# |      1|              AFFECT|     1|      null|       4|Kaseya, Kaduna, N...|             NI|        NI23|10.3463| 7.15295|     -2014903|995763692,9957297...|         guardian.ng|https://guardian....|
# +-------+--------------------+------+----------+--------+--------------------+---------------+------------+-------+--------+-------------+--------------------+--------------------+--------------------+
#
# Wrote to CSV file.
# Showing results of Spark DataFrame 2:
#
# +--------+-------+--------------------+------+------------------+--------+--------------------+---------------+------------+-------+--------+-------------+--------------------+-----------------+--------------------+
# |    DATE|NUMARTS|           COUNTTYPE|NUMBER|        OBJECTTYPE|GEO_TYPE|        GEO_FULLNAME|GEO_COUNTRYCODE|GEO_ADM1CODE|GEO_LAT|GEO_LONG|GEO_FEATUREID|       CAMEOEVENTIDS|          SOURCES|          SOURCEURLS|
# +--------+-------+--------------------+------+------------------+--------+--------------------+---------------+------------+-------+--------+-------------+--------------------+-----------------+--------------------+
# |20210720|      1|          EVACUATION|    12|              null|       4|Jerusalem, Israel...|             IS|        IS00|31.7667| 35.2333|      -797092|995848208,9958465...|       aawsat.com|https://english.a...|
# |20210720|      1|CRISISLEX_T09_DIS...|     3|          patients|       0|                null|           null|        null|   null|    null|         null| 995615383,995615173|        rnz.co.nz|https://www.rnz.c...|
# |20210720|      2|CRISISLEX_C07_SAFETY|     2|Romanian nationals|       1|             Romania|             RO|          RO|     46|      25|           RO|995893352,9958939...|wfmj.com;wfmj.com|https://www.wfmj....|
# +--------+-------+--------------------+------+------------------+--------+--------------------+---------------+------------+-------+--------+-------------+--------------------+-----------------+--------------------+
#
# +-------+--------------------+------+------------------+--------+--------------------+---------------+------------+-------+--------+-------------+--------------------+-----------------+--------------------+
# |NUMARTS|           COUNTTYPE|NUMBER|        OBJECTTYPE|GEO_TYPE|        GEO_FULLNAME|GEO_COUNTRYCODE|GEO_ADM1CODE|GEO_LAT|GEO_LONG|GEO_FEATUREID|       CAMEOEVENTIDS|          SOURCES|          SOURCEURLS|
# +-------+--------------------+------+------------------+--------+--------------------+---------------+------------+-------+--------+-------------+--------------------+-----------------+--------------------+
# |      1|          EVACUATION|    12|              null|       4|Jerusalem, Israel...|             IS|        IS00|31.7667| 35.2333|      -797092|995848208,9958465...|       aawsat.com|https://english.a...|
# |      1|CRISISLEX_T09_DIS...|     3|          patients|       0|                null|           null|        null|   null|    null|         null| 995615383,995615173|        rnz.co.nz|https://www.rnz.c...|
# |      2|CRISISLEX_C07_SAFETY|     2|Romanian nationals|       1|             Romania|             RO|          RO|   46.0|    25.0|           RO|995893352,9958939...|wfmj.com;wfmj.com|https://www.wfmj....|
# +-------+--------------------+------+------------------+--------+--------------------+---------------+------------+-------+--------+-------------+--------------------+-----------------+--------------------+
#
# Wrote to CSV file.
# Showing results of Spark DataFrame 1:
#
# Spark DF 1 Transformed.
# +-------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------+--------------------+
# |NUMARTS|              THEMES|           LOCATIONS|             PERSONS|       ORGANIZATIONS|                TONE|       CAMEOEVENTIDS|       SOURCES|          SOURCEURLS|
# +-------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------+--------------------+
# |      1|TAX_FNCACT;TAX_FN...|2#Maine, United S...|                null|                null|1.25,3.4375,2.187...|                null|      wmtw.com|https://www.wmtw....|
# |      1|ARREST;SOC_GENERA...|2#New York, Unite...|chelsey cochran;j...|maine state polic...|-1.01010101010101...| 996109916,996109917|nbcnewyork.com|https://www.nbcne...|
# |      1|TAX_WORLDLANGUAGE...|3#Portland, Orego...|samuel watkins;ch...|portland police b...|-4.69135802469136...|995961374,9961139...|      kake.com|https://www.kake....|
# +-------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------+--------------------+
#
# Wrote to CSV File.
# Showing results of Spark DataFrame 2:
#
# +--------+-------+--------------------+------+----------+--------+--------------------+---------------+------------+-------+--------+-------------+--------------------+--------------------+--------------------+
# |    DATE|NUMARTS|           COUNTTYPE|NUMBER|OBJECTTYPE|GEO_TYPE|        GEO_FULLNAME|GEO_COUNTRYCODE|GEO_ADM1CODE|GEO_LAT|GEO_LONG|GEO_FEATUREID|       CAMEOEVENTIDS|             SOURCES|          SOURCEURLS|
# +--------+-------+--------------------+------+----------+--------+--------------------+---------------+------------+-------+--------+-------------+--------------------+--------------------+--------------------+
# |20210721|      2|  CRISISLEX_T03_DEAD|     2|      null|       4|Tiruppur, Tamil N...|             IN|        IN25|   11.1|   77.35|     -2113268|                null|thehindu.com;theh...|https://www.thehi...|
# |20210721|      1|               WOUND|     5|      null|       1|      United Kingdom|             UK|          UK|     54|      -4|           UK|995999023,9959990...|       thejournal.ie|https://www.thejo...|
# |20210721|      1|CRISISLEX_T01_CAU...|    25|      null|       4|Gongyi, Guangdong...|             CH|        CH30|22.4423| 112.768|     -1906905|                null|              tnp.sg|https://www.tnp.s...|
# +--------+-------+--------------------+------+----------+--------+--------------------+---------------+------------+-------+--------+-------------+--------------------+--------------------+--------------------+
#
# +-------+--------------------+------+----------+--------+--------------------+---------------+------------+-------+--------+-------------+--------------------+--------------------+--------------------+
# |NUMARTS|           COUNTTYPE|NUMBER|OBJECTTYPE|GEO_TYPE|        GEO_FULLNAME|GEO_COUNTRYCODE|GEO_ADM1CODE|GEO_LAT|GEO_LONG|GEO_FEATUREID|       CAMEOEVENTIDS|             SOURCES|          SOURCEURLS|
# +-------+--------------------+------+----------+--------+--------------------+---------------+------------+-------+--------+-------------+--------------------+--------------------+--------------------+
# |      2|  CRISISLEX_T03_DEAD|     2|      null|       4|Tiruppur, Tamil N...|             IN|        IN25|   11.1|   77.35|     -2113268|                null|thehindu.com;theh...|https://www.thehi...|
# |      1|               WOUND|     5|      null|       1|      United Kingdom|             UK|          UK|   54.0|    -4.0|           UK|995999023,9959990...|       thejournal.ie|https://www.thejo...|
# |      1|CRISISLEX_T01_CAU...|    25|      null|       4|Gongyi, Guangdong...|             CH|        CH30|22.4423| 112.768|     -1906905|                null|              tnp.sg|https://www.tnp.s...|
# +-------+--------------------+------+----------+--------+--------------------+---------------+------------+-------+--------+-------------+--------------------+--------------------+--------------------+
#
# Wrote to CSV file.
# Showing results of Spark DataFrame 1:
#
# Spark DF 1 Transformed.
# +-------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |NUMARTS|              THEMES|           LOCATIONS|             PERSONS|       ORGANIZATIONS|                TONE|       CAMEOEVENTIDS|             SOURCES|          SOURCEURLS|
# +-------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |      1|EPU_ECONOMY_HISTO...|1#Germany#GM#GM#5...|scott griffith;lo...|google;bloomberg;...|2.71966527196653,...|996126547,9961738...|  arkansasonline.com|https://www.arkan...|
# |      1|ARREST;SOC_GENERA...|2#New York, Unite...|chelsey cochran;j...|maine state polic...|-1.01010101010101...| 996128899,996128900|            necn.com|https://www.necn....|
# |      1|TAX_ETHNICITY;TAX...|1#Germany#GM#GM#5...|                null|                null|4.34782608695652,...|                null|northcountrypubli...|https://www.north...|
# +-------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
#
# Wrote to CSV File.
# Showing results of Spark DataFrame 2:
#
# +--------+-------+--------------------+------+----------+--------+--------------------+---------------+------------+---------+----------+-------------+-------------+--------------------+--------------------+
# |    DATE|NUMARTS|           COUNTTYPE|NUMBER|OBJECTTYPE|GEO_TYPE|        GEO_FULLNAME|GEO_COUNTRYCODE|GEO_ADM1CODE|  GEO_LAT|  GEO_LONG|GEO_FEATUREID|CAMEOEVENTIDS|             SOURCES|          SOURCEURLS|
# +--------+-------+--------------------+------+----------+--------+--------------------+---------------+------------+---------+----------+-------------+-------------+--------------------+--------------------+
# |20210722|      2|  CRISISLEX_T03_DEAD|     2|      null|       4|Tiruppur, Tamil N...|             IN|        IN25|     11.1|     77.35|     -2113268|         null|thehindu.com;theh...|https://www.thehi...|
# |20210722|      1|CRISISLEX_T02_INJ...|     2|      cats|       1|             Grenada|             GJ|          GJ|12.116667|-61.666667|           GJ|         null|         stuff.co.nz|https://www.stuff...|
# |20210722|      1|CRISISLEX_T09_DIS...|     3|      null|       2|Oregon, United St...|             US|        USOR|  44.5672|  -122.127|           OR|         null|           abc10.com|https://www.abc10...|
# +--------+-------+--------------------+------+----------+--------+--------------------+---------------+------------+---------+----------+-------------+-------------+--------------------+--------------------+
#
# +-------+--------------------+------+----------+--------+--------------------+---------------+------------+---------+----------+-------------+-------------+--------------------+--------------------+
# |NUMARTS|           COUNTTYPE|NUMBER|OBJECTTYPE|GEO_TYPE|        GEO_FULLNAME|GEO_COUNTRYCODE|GEO_ADM1CODE|  GEO_LAT|  GEO_LONG|GEO_FEATUREID|CAMEOEVENTIDS|             SOURCES|          SOURCEURLS|
# +-------+--------------------+------+----------+--------+--------------------+---------------+------------+---------+----------+-------------+-------------+--------------------+--------------------+
# |      2|  CRISISLEX_T03_DEAD|     2|      null|       4|Tiruppur, Tamil N...|             IN|        IN25|     11.1|     77.35|     -2113268|         null|thehindu.com;theh...|https://www.thehi...|
# |      1|CRISISLEX_T02_INJ...|     2|      cats|       1|             Grenada|             GJ|          GJ|12.116667|-61.666668|           GJ|         null|         stuff.co.nz|https://www.stuff...|
# |      1|CRISISLEX_T09_DIS...|     3|      null|       2|Oregon, United St...|             US|        USOR|  44.5672|  -122.127|           OR|         null|           abc10.com|https://www.abc10...|
# +-------+--------------------+------+----------+--------+--------------------+---------------+------------+---------+----------+-------------+-------------+--------------------+--------------------+
#
# Wrote to CSV file.

# %%
dp.s3_copy_delete()

# %%
dp.remove_file_folders()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# OEC.
# 20210719.gkg.csv
# 20210719.gkgcounts.csv
# 20210720.gkg.csv
# 20210720.gkgcounts.csv
# 20210721.gkg.csv
# 20210721.gkgcounts.csv
# 20210722.gkg.csv
# 20210722.gkgcounts.csv
# Data_Stream_1/
# Data_Stream_1/20210719.gkg.csv
# Data_Stream_1/20210720.gkg.csv
# Data_Stream_1/20210721.gkg.csv
# Data_Stream_1/20210722.gkg.csv
# Data_Stream_2/
# Data_Stream_2/20210719.gkgcounts.csv
# Data_Stream_2/20210720.gkgcounts.csv
# Data_Stream_2/20210721.gkgcounts.csv
# Data_Stream_2/20210722.gkgcounts.csv
# Scraped_OEC_Files/
# Step6_Capstone_Project.py
# _metadata
# e-49BHK71LSN43O8WH0G07XHU9W/.aws-editors-workspace-metadata/
# e-49BHK71LSN43O8WH0G07XHU9W/.aws-editors-workspace-metadata/file-perm.sqlite
# e-49BHK71LSN43O8WH0G07XHU9W/.aws-editors-workspace-metadata/kernels/
# e-49BHK71LSN43O8WH0G07XHU9W/.aws-editors-workspace-metadata/kernels/pysparkkernel/
# e-49BHK71LSN43O8WH0G07XHU9W/.aws-editors-workspace-metadata/kernels/pysparkkernel/__init__.py
# e-49BHK71LSN43O8WH0G07XHU9W/.aws-editors-workspace-metadata/kernels/pysparkkernel/__pycache__/
# e-49BHK71LSN43O8WH0G07XHU9W/.aws-editors-workspace-metadata/kernels/pysparkkernel/__pycache__/__init__.cpython-37.pyc
# e-49BHK71LSN43O8WH0G07XHU9W/.aws-editors-workspace-metadata/kernels
gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/applications/hadoop-hdfs/hadoop-hdfs-datanode-ip-172-31-15-35.log.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/applications/hadoop-hdfs/hadoop-hdfs-datanode-ip-172-31-15-35.out.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/applications/hadoop-yarn/yarn-yarn-nodemanager-ip-172-31-15-35.log.2021-07-17-20.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/applications/hadoop-yarn/yarn-yarn-nodemanager-ip-172-31-15-35.log.2021-07-17-21.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/applications/hadoop-yarn/yarn-yarn-nodemanager-ip-172-31-15-35.log.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/applications/hadoop-yarn/yarn-yarn-nodemanager-ip-172-31-15-35.out.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/daemons/instance-state/console.log-2021-07-17-20-42.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/daemons/instance-state/instance-state.log-2021-07-17-20-45.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/daemons/instance-state/instance-state.log-2021-07-17-21-00.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/daemons/instance-state/instance-state.log-2021-07-17-21-15.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/daemons/instance-state/instance-state.log-2021-07-17-21-30.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/daemons/instance-state/instance-state.log-2021-07-17-21-45.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/daemons/instance-state/instance-state.log-2021-07-17-22-00.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/daemons/instance-state/instance-state.log-2021-07-17-22-15.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/daemons/setup-dns.log.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/provision-node/130c5d3d-d20d-40e6-a759-afc3ab35978b/controller.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/provision-node/130c5d3d-d20d-40e6-a759-afc3ab35978b/stderr.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/provision-node/apps-phase/0/130c5d3d-d20d-40e6-a759-afc3ab35978b/puppet.log.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/provision-node/apps-phase/0/130c5d3d-d20d-40e6-a759-afc3ab35978b/stderr.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/provision-node/apps-phase/0/130c5d3d-d20d-40e6-a759-afc3ab35978b/stdout.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/provision-node/apps-phase/install.stderr.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/provision-node/reports/0/130c5d3d-d20d-40e6-a759-afc3ab35978b/ip-172-31-15-35.ec2.internal/202107172045.puppetreport.json.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/provision-node/reports/0/130c5d3d-d20d-40e6-a759-afc3ab35978b/ip-172-31-15-35.ec2.internal/202107172045.yaml.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/setup-devices/DiskEncryptor.log.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/setup-devices/setup_drives.log.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/setup-devices/setup_emr_metrics.log.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/setup-devices/setup_tmp_dir.log.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/setup-devices/setup_var_cache_dir.log.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/setup-devices/setup_var_lib_dir.log.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/setup-devices/setup_var_log_dir.log.gz
# j-Z6ZZT32P5EJF/node/i-0e73e234c8dca1244/setup-devices/setup_var_tmp_dir.log.gz
# j-Z6ZZT32P5EJF/steps/s-2SS43CZV1HP3A/controller.gz
# j-Z6ZZT32P5EJF/steps/s-2SS43CZV1HP3A/stderr.gz

# %%
s3_uri = "s3://openendedcapstone/20210714.gkgcounts.csv"
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
dp.remove_other_files()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# OEC.
# 20210719
# Other Files deleted.
# 20210719.gkgco
# Other Files deleted.
# 20210720
# Other Files deleted.
# 20210720.gkgco
# Other Files deleted.
# 20210721
# Other Files deleted.
# 20210721.gkgco
# Other Files deleted.
# 20210722
# Other Files deleted.
# 20210722.gkgco
# Other Files deleted.
# Data_Stream_1/20210719
# Other files deleted.
# Data_Stream_1/20210720
# Other files deleted.
# Data_Stream_1/20210721
# Other files deleted.
# Data_Stream_1/20210722
# Other files deleted.
# Data_Stream_2/20210719.gkgco
# Other Files deleted.
# Data_Stream_2/20210720.gkgco
# Other Files deleted.
# Data_Stream_2/20210721.gkgco
# Other Files deleted.
# Data_Stream_2/20210722.gkgco
# Other Files deleted.

# %% [markdown]
# # DONE! Check S3 Bucket.

# %% [markdown]
# # Problem: I was able to drop columns, but not save to S3 file path.

# %% [markdown]
# # Next is to try uploading all files.
